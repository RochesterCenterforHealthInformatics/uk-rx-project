# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium

# %%
ccg_gdf = gpd.read_file('uk_ccg.geojson')
ccg_gdf.head(3)
# Out:
#                                    Name  \
# 0                            Darlington
# 1  Durham Dales, Easington & Sedgefield
# 2                          North Durham
#
#                                          description timestamp begin   end  \
# 0  <br><br><br>\n    <table border="1" padding="0...      None  None  None
# 1  <br><br><br>\n    <table border="1" padding="0...      None  None  None
# 2  <br><br><br>\n    <table border="1" padding="0...      None  None  None
#
#     altitudeMode tessellate extrude visibility drawOrder  icon  \
# 0  clampToGround          1       1          1      None  None
# 1  clampToGround          1       1          1      None  None
# 2  clampToGround          1       1          1      None  None
#
#                                             geometry
# 0  POLYGON Z ((-1.407325 54.593612 0, -1.423288 5...
# 1  POLYGON Z ((-1.241902 54.722729 0, -1.272867 5...
# 2  POLYGON Z ((-1.403257 54.760033 0, -1.407503 5...

# %%
fig, ax = plt.subplots(figsize=(20,30))
ccg_gdf.plot(ax=ax, edgecolor='black')

# %%
uk_centroid = [53.8060835,-1.6057716]
m = folium.Map(uk_centroid, zoom_start=6)
folium.GeoJson('uk_ccg.geojson', name='geojson').add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
